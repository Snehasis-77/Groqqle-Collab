# %%
# !git clone https://github.com/jgravelle/Groqqle.git
# %cd Groqqle
# !pip install -q condacolab
import condacolab
condacolab.install()
# !mamba create --name groqqle python=3.11 -y
# !source activate groqqle
# !pip install -r requirements.txt
import os
os.environ["GROQ_API_KEY"] = "your_groq_api-key"  # Replace with your actual API key
# !streamlit run Groqqle.py & npx localtunnel --port 8501
# Out:
# fatal: destination path 'Groqqle' already exists and is not an empty directory.
# /content/Groqqle
# ✨🍰✨ Everything looks OK!
#
# Looking for: ['python=3.11']
#
# conda-forge/linux-64                                        Using cache
# conda-forge/noarch                                          Using cache
# Transaction
#
#   Prefix: /usr/local/envs/groqqle
#
#   Updating specs:
#
#    - python=3.11
#
#
#   Package               Version  Build               Channel           Size
# ─────────────────────────────────────────────────────────────────────────────
#   Install:
# ─────────────────────────────────────────────────────────────────────────────
#
#   + _libgcc_mutex           0.1  conda_forge         conda-forge     Cached
#   + ld_impl_linux-64       2.40  hf3520f5_7          conda-forge     Cached
#   + ca-certificates   2024.8.30  hbcca054_0          conda-forge     Cached
#   + libgomp              14.1.0  h77fa898_1          conda-forge     Cached
# ...
